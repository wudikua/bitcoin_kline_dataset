# %%
import pandas as pd
import numpy as np
import os
import data_loader
from sqlalchemy import create_engine
import requests

data_loader.set_up_proxy('192.168.1.3', 11223, True)
print(data_loader.proxies)

print(requests.get('https://ipinfo.io', proxies=data_loader.proxies).text)
# Out:
# {'http': 'socks5h://192.168.1.3:11223', 'https': 'socks5h://192.168.1.3:11223'}
# {
#   "ip": "45.94.43.134",
#   "hostname": "45.94.43.134.static.xtom.com",
#   "city": "Hong Kong",
#   "region": "Central and Western",
#   "country": "HK",
#   "loc": "22.2783,114.1747",
#   "org": "AS55933 Cloudie Limited",
#   "timezone": "Asia/Hong_Kong",
#   "readme": "https://ipinfo.io/missingauth"
# }

# %%
import importlib
importlib.reload(data_loader)
data_loader.set_up_proxy('192.168.1.3', 11223, True)

data_loader.download_symbol_historty_funding_rate('BTCUSDT', '1101 day ago UTC', '1100 day ago UTC', conf_type='u_heyue')
# Out:
# 2022-10-13 12:16:19 request  https://fapi.binance.com/fapi/v1/fundingRate {'symbol': 'BTCUSDT', 'startTime': '1570508179168', 'endTime': '1570594579165', 'limit': '3'}
#     symbol    fundingTime fundingRate       fundingDate
# 0  BTCUSDT  1570521600000  0.00010000  2019-10-08 16:00
# 1  BTCUSDT  1570550400000  0.00010000  2019-10-09 00:00
# 2  BTCUSDT  1570579200000  0.00010000  2019-10-09 08:00

# %%
import importlib
importlib.reload(data_loader)
data_loader.set_up_proxy('192.168.1.3', 11223, True)

ddf1, ddf2, ddf3, ddf4, ddf5 = data_loader.download_symbol_u_heyue_historty_short_long_ratio('BTCUSDT', '1d','30 day ago UTC', '0 day ago UTC')
# Out:
# 2022-10-14 14:15:05 request  https://fapi.binance.com/futures/data/openInterestHist {'symbol': 'BTCUSDT', 'period': '1d', 'startTime': '1663136105441', 'endTime': '1665728105439', 'limit': '30'}
# 2022-10-14 14:15:05 request  https://fapi.binance.com/futures/data/topLongShortAccountRatio {'symbol': 'BTCUSDT', 'period': '1d', 'startTime': '1663136105441', 'endTime': '1665728105439', 'limit': '30'}
# 2022-10-14 14:15:06 request  https://fapi.binance.com/futures/data/topLongShortPositionRatio {'symbol': 'BTCUSDT', 'period': '1d', 'startTime': '1663136105441', 'endTime': '1665728105439', 'limit': '30'}
# 2022-10-14 14:15:06 request  https://fapi.binance.com/futures/data/globalLongShortAccountRatio {'symbol': 'BTCUSDT', 'period': '1d', 'startTime': '1663136105441', 'endTime': '1665728105439', 'limit': '30'}
# ...

# %%
ddf5
# Out:
#    market_cate1 market_cate2  symbol buySellRatio          buy         sell  \
# 0          1000         1002     NaN       0.9747  328187.1620  336722.0200
# 1          1000         1002     NaN       0.9906  270787.4620  273355.2490
# 2          1000         1002     NaN       1.0574  171910.6750  162582.0980
# 3          1000         1002     NaN       0.9330  240982.1660  258287.7200
# 4          1000         1002     NaN       0.9887  493427.8840  499055.4030
# 5          1000         1002     NaN       0.9869  394317.7110  399559.4070
# 6          1000         1002     NaN       1.0064  584184.2770  580453.1010
# 7          1000         1002     NaN       1.0478  436069.0550  416180.3120
# 8          1000         1002     NaN       0.9996  418775.6090  418925.4150
# 9          1000         1002     NaN       0.9883  187395.6780  189608.8670
# 10         1000         1002     NaN       0.9700  201912.7810  208155.3110
# ...

# %%
import importlib
importlib.reload(data_loader)
data_loader.set_up_proxy('192.168.1.3', 11223, True)

df1, df2, df3, df4, df5, df6 = data_loader.download_symbol_bi_heyue_historty_short_long_ratio('DOTUSD_PERP', '1d','30 day ago UTC', '0 day ago UTC')
# Out:
# 2022-10-14 11:41:49 request  https://dapi.binance.com/futures/data/openInterestHist {'pair': 'DOTUSD', 'period': '1d', 'startTime': '1663126909346', 'endTime': '1665718909344', 'limit': '30', 'contractType': 'PERPETUAL'}
# 2022-10-14 11:41:49 request  https://dapi.binance.com/futures/data/topLongShortAccountRatio {'pair': 'DOTUSD', 'period': '1d', 'startTime': '1663126909346', 'endTime': '1665718909344', 'limit': '30'}
# 2022-10-14 11:41:49 request  https://dapi.binance.com/futures/data/topLongShortPositionRatio {'pair': 'DOTUSD', 'period': '1d', 'startTime': '1663126909346', 'endTime': '1665718909344', 'limit': '30'}
# 2022-10-14 11:41:50 request  https://dapi.binance.com/futures/data/globalLongShortAccountRatio {'pair': 'DOTUSD', 'period': '1d', 'startTime': '1663126909346', 'endTime': '1665718909344', 'limit': '30'}
# ...

# %%
from binance.helpers import convert_ts_str

def download_symbol_historty_funding_rate(symbol, start_str, end_str, conf_type='bi_heyue', maxLimit=1000):
    endTime = convert_ts_str(end_str)
    finalStartTime = convert_ts_str(start_str)
    if finalStartTime == endTime:
        return pd.DataFrame({})
    startTime = endTime
    result = []
    while startTime >= finalStartTime:
        limit = maxLimit
        startTime = endTime - 8 * 60 * 60 * 1000 * limit
        startTime = max(startTime, finalStartTime)
        deltaTime = (endTime - startTime) / 1000
        limit = math.ceil(deltaTime / (8 * 60 * 60))
        status, info, headers = binance_request(uri=API_CONF[conf_type]['fund_rate'], host=API_CONF[conf_type]['host'],
                                                header={
                                                    'symbol': str(symbol), 'startTime': str(startTime),
                                                    'endTime': str(endTime), 'limit': str(limit)
                                                })
        if status != 200 or len(info) == 0:
            break
        endTime = startTime
        result.extend(info)

    df = pd.DataFrame(result,
                      columns=['symbol', 'fundingTime', 'fundingRate']).sort_values('open_ts')

# %%
"1234".replace('1', '#').replace('2', '>')
# Out:
# '#>34'

# %%
import zlib
zlib.crc32(b'btcusdt')

# %%
db_engine = create_engine('mysql+pymysql://root:mengjun1990@localhost:3306/findata')

# %%
df = pd.read_sql(sql='select trd_amt,symbol,close,open_dt from kline where `interval`="1d" and market_cate2="1002" and open_dt>="2021-06-01" and open_dt<="2021-10-01"', con=db_engine)
df
# Out:
#             trd_amt        symbol     close             open_dt
# 0      3.317017e+08  1000SHIBUSDT  0.008826 2021-06-01 08:00:00
# 1      4.903798e+08  1000SHIBUSDT  0.009429 2021-06-02 08:00:00
# 2      3.238493e+08  1000SHIBUSDT  0.009772 2021-06-03 08:00:00
# 3      3.388585e+08  1000SHIBUSDT  0.008770 2021-06-04 08:00:00
# 4      1.849243e+08  1000SHIBUSDT  0.008415 2021-06-05 08:00:00
# ...             ...           ...       ...                 ...
# 13692  3.921817e+07       ZRXUSDT  0.893300 2021-09-26 08:00:00
# 13693  2.056617e+07       ZRXUSDT  0.850400 2021-09-27 08:00:00
# 13694  2.413445e+07       ZRXUSDT  0.813900 2021-09-28 08:00:00
# 13695  1.910238e+07       ZRXUSDT  0.832300 2021-09-29 08:00:00
# 13696  2.174852e+07       ZRXUSDT  0.913900 2021-09-30 08:00:00
#
# [13697 rows x 4 columns]

# %%
df.trd_amt.mean()
# Out:
# 463876883.99791753

# %%
# !pip install sea

# %%
import seaborn as sns
import matplotlib.pyplot as plt

new_df_data = {}
for s in df.symbol.unique():
    if 'USDT' not in s:
        continue
    s_df = df[df['symbol']==s].sort_values('open_dt')
    close = s_df.close.values
    if s_df.trd_amt.values[0]<263876883:
        continue
    # print(len(close))
    if len(close) == 122:
        new_df_data[s] = close
new_df = pd.DataFrame(new_df_data)
plt.subplots(figsize=(20,15))
ax = plt.axes()
ax.set_title("Correlation Heatmap")
corr = new_df.corr()
sns.heatmap(corr, 
            annot=True,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
# Out:
# <AxesSubplot: title={'center': 'Correlation Heatmap'}>

# %%
corr
# Out:
#               1000LUNCBUSD  1000SHIBBUSD  1000SHIBUSDT  1000XECUSDT  \
# 1000LUNCBUSD      1.000000      0.510177      0.509986     0.244311
# 1000SHIBBUSD      0.510177      1.000000      0.999990     0.852190
# 1000SHIBUSDT      0.509986      0.999990      1.000000     0.852164
# 1000XECUSDT       0.244311      0.852190      0.852164     1.000000
# 1INCHUSDT         0.231292      0.794033      0.794337     0.734534
# ...                    ...           ...           ...          ...
# YFIUSDT           0.490964      0.910270      0.910081     0.761311
# ZECUSDT           0.479795      0.957952      0.957466     0.796393
# ZENUSDT           0.459513      0.968433      0.968332     0.810582
# ZILUSDT           0.457267      0.930781      0.930882     0.779304
# ZRXUSDT           0.482876      0.933238      0.933094     0.791904
#
#               1INCHUSDT  AAVEUSDT   ADABUSD   ADAUSDT  ALGOUSDT  ALICEUSDT  \
# ...

# %%
for k,v in corr['VETUSDT'].sort_values().items():
    if 'USDT' in k:
        print("{} {}".format(k,v))
# Out:
# BTCDOMUSDT -0.641204447515085
# REEFUSDT -0.5202763159447514
# XRPUSDT -0.519244378681968
# BNXUSDT -0.39695703088223366
# COMPUSDT -0.35894383711433975
# CHZUSDT -0.34134537970321627
# ALGOUSDT -0.27873850785925186
# XLMUSDT -0.21457922035019505
# RSRUSDT -0.1854870971979306
# APEUSDT -0.1749399320700641
# COTIUSDT -0.13592832751351
# MKRUSDT 0.017314141698824385
# ENSUSDT 0.027997332880869766
# INJUSDT 0.05123013077400726
# PEOPLEUSDT 0.17646442158319617
# HNTUSDT 0.2634180261037723
# LINKUSDT 0.26953071300841086
# EGLDUSDT 0.3643544012738767
# LITUSDT 0.38542861161824366
# ATOMUSDT 0.42310252352105365
# FOOTBALLUSDT 0.430211586420992
# RVNUSDT 0.4574519983719377
# IOTAUSDT 0.480328192944052
# RLCUSDT 0.4955780131629119
# SUSHIUSDT 0.49835784718663184
# UNIUSDT 0.5397265492922414
# GALUSDT 0.6084703404100148
# HBARUSDT 0.6136357009204053
# SOLUSDT 0.6236237044905553
# BLZUSDT 0.6716491782677871
# TRBUSDT 0.6876211592186432
# LINAUSDT 0.6945127847602506
# ...

# %%
b'123'

# %%
data_loader.insert_or_update_exchange_info(db_engine, exchange_info)

# %%
exchange_info['xianhuo']

# %%
exchange_info['bi_heyue']

# %%
exchange_info['u_heyue']

# %%
exchange_info['qiquan']

# %%
ttype = 'xianhuo'
interval = '1h'


exchange_info = data_loader.get_info()

trading_symbols = exchange_info[ttype][exchange_info[ttype]['status']=='TRADING']
if 'heyue' in ttype:
    trading_symbols = trading_symbols[trading_symbols['contractType']=='PERPETUAL'].symbol.values
else:
    trading_symbols = trading_symbols.symbol.values

db_engine = create_engine('mysql+pymysql://root:mengjun1990@localhost:3306/findata')
db_symbols = data_loader.get_db_symbols(db_engine)

for symbol in trading_symbols:
    data_loader.auto_update_data(symbol, interval, exchange_info, ttype, db_symbols, db_engine)
